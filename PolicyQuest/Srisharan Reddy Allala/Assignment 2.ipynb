# %%
import matplotlib.pyplot as plt
import gymnasium as gym
import numpy as np

# ── Custom Reward Wrapper ─────────────────────────────────────────────────────

class FrozenLakeCustomReward(gym.RewardWrapper):
    def __init__(self, env, rewards=None):
        super().__init__(env)
        self.rewards = rewards or {"G": 100.0, "H": -50.0, "F": -1.0}

    def reward(self, reward):
        desc = self.unwrapped.desc
        s    = self.unwrapped.s
        ncol = self.unwrapped.ncol
        row, col = divmod(s, ncol)
        tile = desc[row, col].decode("utf-8")
        if tile == "G":
            return self.rewards["G"]
        elif tile == "H":
            return self.rewards["H"]
        else:
            return self.rewards["F"]


def build_env(slippery=False, rewards=None):
    base_env = gym.make("FrozenLake8x8-v1", is_slippery=slippery, render_mode="ansi")
    return FrozenLakeCustomReward(base_env)   # wrap it — everything else stays the same

def plot_policy_on_frozen_lake(env, policy, title="FrozenLake policy"):
    desc = np.asarray(env.unwrapped.desc, dtype=str)
    policy_grid = np.asarray(policy).reshape(desc.shape)
    arrows = np.array(["<", "v", ">", "^"])
    colors = {
        "S": "#9be7a1",
        "F": "#dceefb",
        "H": "#3a3a3a",
        "G": "#ffd54f",
    }

    fig, ax = plt.subplots(figsize=(8, 8))
    for r in range(desc.shape[0]):
        for c in range(desc.shape[1]):
            tile = desc[r, c]
            rect = plt.Rectangle((c, desc.shape[0] - 1 - r), 1, 1, facecolor=colors[tile], edgecolor="black", linewidth=1.5)
            ax.add_patch(rect)

            if tile == "H":
                label = "H"
            elif tile == "G":
                label = "G"
            elif tile == "S":
                label = f"S{arrows[policy_grid[r, c]]}"
            else:
                label = arrows[policy_grid[r, c]]

            ax.text(c + 0.5, desc.shape[0] - 1 - r + 0.5, label, ha="center", va="center", fontsize=16, fontweight="bold", color="black")

    ax.set_xlim(0, desc.shape[1])
    ax.set_ylim(0, desc.shape[0])
    ax.set_xticks(np.arange(desc.shape[1] + 1))
    ax.set_yticks(np.arange(desc.shape[0] + 1))
    ax.grid(True, color="black", linewidth=1.0)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_aspect("equal")
    ax.set_title(title)
    plt.tight_layout()
    plt.show()

def policy_evaluate_graphical(env, policy, eval_episodes=100, max_steps=100):
    """
    Evaluates the performance of a policy strictly from the starting point.
    Returns average reward and average episode length.
    """
    total_rewards = []
    episode_lengths = []

    for _ in range(eval_episodes):
        state, _ = env.reset()
        episode_reward = 0
        steps = 0

        for _ in range(max_steps):
            action = policy[state]
            next_state, reward, terminated, truncated, _ = env.step(action)
            
            episode_reward += reward
            steps += 1

            if terminated or truncated:
                break
            
            state = next_state

        total_rewards.append(episode_reward)
        episode_lengths.append(steps)

    return np.mean(total_rewards), np.mean(episode_lengths)

def plot_evaluation_metrics(avg_rewards, avg_lengths):
    """
    Plots the collected metrics from policy_iteration, updated for 
    the new reward scheme (-50 hole, 100 goal, -1 step).
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Plot Average Reward
    ax1.plot(avg_rewards, marker='o', color='forestgreen', label='Avg Reward', linewidth=2)
    ax1.axhline(y=0, color='crimson', linestyle='-', alpha=0.5, label='Zero Reward Line')
    ax1.axhline(y=100, color='gold', linestyle='--', alpha=0.8, label='Max Goal Reward (100)')
    
    # Dynamically scale the y-axis to capture negative values well, but keep top above 100
    y_min = min(-60.0, min(avg_rewards) - 10) if avg_rewards else -60.0
    ax1.set_ylim([y_min, 110.0])

    ax1.set_title("Average Reward per Iteration", fontsize=12)
    ax1.set_xlabel("Policy Iteration", fontsize=10)
    ax1.set_ylabel("Average Reward", fontsize=10)
    ax1.grid(True, linestyle='--', alpha=0.7)
    ax1.legend()

    # Plot Average Episode Length
    ax2.plot(avg_lengths, marker='o', color='royalblue', linewidth=2)
    ax2.set_title("Average Episode Length per Iteration", fontsize=12)
    ax2.set_xlabel("Policy Iteration", fontsize=10)
    ax2.set_ylabel("Average Steps", fontsize=10)
    ax2.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# %%
import random
from tqdm import tqdm

def policy_evaluation_monte_epsilon(policy, n_actions, epsilon, gamma, n_episodes=10000, max_steps=100, iteration_idx=1, slippery=False,rewards=None):
    n_states = policy.shape[0]
    env = build_env(slippery=slippery, rewards=rewards)
    
    q_sum = np.zeros((n_states, env.action_space.n))
    returns_count = np.zeros((n_states, env.action_space.n))
    
    for episode in tqdm(range(n_episodes), desc=f"Iter {iteration_idx} MC Eval", leave=False, position=1):
        env.reset()
        episode_history = []
        
        state = random.randint(0, n_states - 1) 
        env.unwrapped.s = state 
        
        action = random.randint(0, env.action_space.n - 1)
        
        #episode generation 
        for step in range(max_steps):
            next_state, reward, terminated, truncated, info = env.step(action)
            
            episode_history.append((state, action, reward))
            
            if terminated or truncated:
                break
                
            state = next_state
            action = np.random.choice(n_actions, p=policy[state]) 

        #episode return
        G = 0
        visited_in_episode = set()
        
        for t in reversed(range(len(episode_history))):
            s_t, a_t, r_t = episode_history[t]
            
            G = r_t + gamma * G
            
            if (s_t, a_t) not in visited_in_episode:
                visited_in_episode.add((s_t, a_t))
                q_sum[s_t, a_t] += G
                returns_count[s_t, a_t] += 1
            
    env.close()
    q_values_matrix = np.divide(q_sum, returns_count, out=np.zeros_like(q_sum), where=returns_count != 0)
    return q_values_matrix

# %%
import random
from tqdm import tqdm

def policy_evaluation_monte_off(policy, gamma, n_episodes=10000, max_steps=100, iteration_idx=1, slippery=False,rewards=None):
    n_states = policy.shape[0]
    env = build_env(slippery=slippery, rewards=rewards)
    
    q_values = np.zeros((n_states, env.action_space.n))
    cummilatice_weights = np.zeros((n_states, env.action_space.n))
    
    for episode in tqdm(range(n_episodes), desc=f"Iter {iteration_idx} MC Eval", leave=False, position=1):
        env.reset()
        episode_history = []
        
        #state = random.randint(0, n_states - 1) 
        #env.unwrapped.s = state 
        
        action = random.randint(0, env.action_space.n - 1)
        
        #episode generation 
        for step in range(max_steps):
            next_state, reward, terminated, truncated, info = env.step(action)
            
            episode_history.append((state, action, reward))
            
            if terminated or truncated:
                break
                
            state = next_state
            action = random.randint(0, env.action_space.n - 1) 

        #episode return
        G = 0
        W = 1.0
        
        for t in reversed(range(len(episode_history))):
            s_t, a_t, r_t = episode_history[t]
            
            G = r_t + gamma * G
            
            cummilatice_weights[s_t, a_t] += W
            q_values[s_t, a_t] += (W / cummilatice_weights[s_t, a_t]) * (G - q_values[s_t, a_t])
            
            if a_t != policy[s_t]:
                break
            
            W = W * env.action_space.n

    env.close()
    return q_values

# %%
def policy_iteration_epsilon(env, gamma=0.99, max_iterations=100, slippery=False, episodes = 1000, max_steps=100, epsilon = 0.1, rewards=None):
   
    n_states = env.observation_space.n
    n_actions = env.action_space.n
    policy = np.ones((n_states, n_actions)) / n_actions
    
    avg_rewards_history = []
    avg_lengths_history = []

    outer_pbar = tqdm(total=max_iterations, desc="Overall Policy Iterations", position=0, leave=True)

    for iteration in range(max_iterations):
        avg_r, avg_l = policy_evaluate_graphical(env, np.argmax(policy, axis=1))
        avg_rewards_history.append(avg_r)
        avg_lengths_history.append(avg_l)


        q_val_matrix = policy_evaluation_monte_epsilon(policy, n_actions,epsilon, gamma, iteration_idx=iteration + 1, slippery=slippery, n_episodes=episodes, max_steps=max_steps, rewards=rewards)
        
        greedy_action = np.argmax(q_val_matrix, axis=1)
        new_policy = np.full((n_states, n_actions), epsilon / n_actions)
        new_policy[np.arange(n_states), greedy_action] = 1.0 - epsilon + epsilon / n_actions
        
        
        # if np.array_equal(new_policy, policy):
        #     outer_pbar.update(1)
        #     outer_pbar.close()
        #     print(f"\nPolicy converged after {iteration + 1} iterations!")
        #     return policy, avg_rewards_history, avg_lengths_history
            
        policy = new_policy
        outer_pbar.update(1)

    outer_pbar.close()
    return policy, avg_rewards_history, avg_lengths_history

# %%
def off_policy_iteration(env, gamma=0.99, max_iterations=100, slippery=False, episodes = 1000, max_steps=100, rewards=None):
   
    n_states = env.observation_space.n

    policy = np.zeros(n_states, dtype=int)  
    
    avg_rewards_history = []
    avg_lengths_history = []

    outer_pbar = tqdm(total=max_iterations, desc="Overall Policy Iterations", position=0, leave=True)

    for iteration in range(max_iterations):
        avg_r, avg_l = policy_evaluate_graphical(env, policy)
        avg_rewards_history.append(avg_r)
        avg_lengths_history.append(avg_l)


        q_val_matrix = policy_evaluation_monte_off(policy, gamma, iteration_idx=iteration + 1, slippery=slippery, n_episodes=episodes, max_steps=max_steps, rewards=rewards)
        
        new_policy = np.argmax(q_val_matrix, axis=1)
        
        
        # if np.array_equal(new_policy, policy):
        #     outer_pbar.update(1)
        #     outer_pbar.close()
        #     print(f"\nPolicy converged after {iteration + 1} iterations!")
        #     return policy, avg_rewards_history, avg_lengths_history
            
        policy = new_policy
        outer_pbar.update(1)

    outer_pbar.close()
    return policy, avg_rewards_history, avg_lengths_history

# %%
def run(gamma=0.99, episodes=1000, max_steps=100, max_iterations=100, slippery=False, epsilon=0.1, mode="on_policy", rewards=None):
    
    env = build_env(slippery=slippery, rewards=rewards)
    
    if mode == "on_policy":
        pi_policy, avg_rewards, avg_lengths = policy_iteration_epsilon(env,gamma=gamma, max_iterations=max_iterations, slippery=slippery, episodes=episodes, max_steps=max_steps, epsilon=epsilon)
        plot_evaluation_metrics(avg_rewards, avg_lengths)
    
        plot_policy_on_frozen_lake(env, np.argmax(pi_policy, axis=1), title="Policy Iteration on FrozenLake 8x8")
    else:
        pi_policy, avg_rewards, avg_lengths = off_policy_iteration(env,gamma=gamma, max_iterations=max_iterations, slippery=slippery, episodes=episodes, max_steps=max_steps)
        plot_evaluation_metrics(avg_rewards, avg_lengths)
        plot_policy_on_frozen_lake(env, pi_policy, title="Off-Policy Iteration on FrozenLake 8x8")

# %%
run(slippery=False, mode="on_policy", episodes=500, max_steps=100, max_iterations=100, epsilon=0, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 100/100 [00:11<00:00,  8.80it/s]

# %% [markdown]
# With esilon = 0, the model converged to an optimal solution in very few iterations even with only 500 episodes per iteration, and plateaued

# %%
run(slippery=False, mode="on_policy", episodes=10000, max_steps=100, max_iterations=100, epsilon=0.1, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 100/100 [08:52<00:00,  5.33s/it]

# %% [markdown]
# with epsilon 0.1 even with 10000 episodes per iteration, could not converge to ideal moves for all squares within 100 iterations

# %%
run(slippery=False, mode="on_policy", episodes=1000, max_steps=100, max_iterations=1000, epsilon=0.1, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 1000/1000 [11:45<00:00,  1.42it/s]

# %% [markdown]
# increasing iterations to 1000 and decreasing episode length to 1000 made the noise much worse, leading to final policy being worse off

# %%
run(slippery=False, mode="on_policy", episodes=100000, max_steps=100, max_iterations=100, epsilon=0.1, rewards={"G": 100.0, "H": -50.0, "F": -1.0})

# %%
run(slippery=False, mode="on_policy", episodes=5000, max_steps=100, max_iterations=100, epsilon=0.05, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 100/100 [06:58<00:00,  4.18s/it]

# %% [markdown]
# even with epsilon 0.05 alot of noise left even after 5000 episodes per iteration for 100 iterations

# %%
run(slippery=False, mode="on_policy", episodes=1000, max_steps=100, max_iterations=100, epsilon=0, rewards={"G": 100.0, "H": -50.0, "F": -1.0}, gamma = 0.5)
# Out:
# Overall Policy Iterations: 100%|██████████| 100/100 [01:11<00:00,  1.39it/s]

# %% [markdown]
# gamma 0.5 reduces foresight, as a result policy near the goal is optimal but becomes worse off as we move away

# %%
run(slippery=False, mode="off_policy", episodes=10000, max_steps=100, max_iterations=100, epsilon=0.1, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 100/100 [02:30<00:00,  1.50s/it]

# %%
run(slippery=False, mode="off_policy", episodes=100000, max_steps=100, max_iterations=10, epsilon=0.1, rewards={"G": 100.0, "H": -50.0, "F": -1.0})
# Out:
# Overall Policy Iterations: 100%|██████████| 10/10 [02:57<00:00, 17.72s/it]

# %% [markdown]
# Off policy with random as behaviour policy leads to alot of cells being stuck in their initial state of left even after large number of episodes
